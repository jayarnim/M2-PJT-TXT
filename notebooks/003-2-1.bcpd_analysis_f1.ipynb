# %%
PATH_WORK_DIR = ".."

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import os
os.environ["CUDA_LAUNCH_BLOCKING"] = "1"
os.chdir(PATH_WORK_DIR)
print(f"DIRECTORY: {os.getcwd()}")
# Out:
# DIRECTORY: c:\Users\jayar\Desktop\바탕 화면\REPO\PROJECT\M2-PJT_TXT

# %%
import sys
sys.path.append("src")

# %% [markdown]
# # packages

# %%
from pathlib import Path
import pickle
import arviz as az
import matplotlib.pyplot as plt
from pymyproject.bcpd import analysis

# %% [markdown]
# # data

# %%
PATH = "./result/factor/scores.pkl"
with open(file=PATH, mode="rb") as f:
    scores = pickle.load(f)

# %%
FACTOR = 1
PATH = f"./result/bcpd/f{FACTOR}/"
folder = Path(PATH)

trace = dict()

for i, PATH in enumerate(folder.glob("*.nc")):
    with open(file=PATH, mode="rb") as f:
        trace[i+1] = az.from_netcdf(PATH)

# %% [markdown]
# # convergence diagnostics

# %% [markdown]
# ## N_CPS==1

# %%
N_CPS = 1
data = trace[N_CPS]

# %%
summary = az.summary(data=data)

COND1 = summary["ess_bulk"]<400
COND2 = summary["ess_tail"]<400
COND3 = summary["r_hat"]>1.01
COND4 = summary.index.str.contains("tau_raw")
summary[(COND1 | COND2 | COND3) & (~COND4)]
# Out:
#            mean     sd   hdi_3%  hdi_97%  mcse_mean  mcse_sd  ess_bulk  \
# mus[0]    0.971  0.043    0.882    1.045      0.005    0.003      85.0
# mus[1]   -0.667  0.033   -0.731   -0.606      0.004    0.002      92.0
# tau[0]  271.145  9.156  265.000  294.000      1.765    1.839      53.0
#
#         ess_tail  r_hat
# mus[0]      89.0   1.03
# mus[1]      91.0   1.03
# tau[0]      66.0   1.06

# %%
exclude = {"tau_raw"}

var_names = [
    name for name in data.posterior.data_vars
    if name not in exclude
]

kwargs = dict(
    data=data, 
    var_names=var_names, 
    figsize=(20,12),
)

az.plot_trace(**kwargs)
plt.show()

# %% [markdown]
# ## N_CPS==2

# %%
N_CPS = 2
data = trace[N_CPS]

# %%
summary = az.summary(data=data)

COND1 = summary["ess_bulk"]<400
COND2 = summary["ess_tail"]<400
COND3 = summary["r_hat"]>1.01
COND4 = summary.index.str.contains("tau_raw")
summary[(COND1 | COND2 | COND3) & (~COND4)]
# Out:
# Empty DataFrame
# Columns: [mean, sd, hdi_3%, hdi_97%, mcse_mean, mcse_sd, ess_bulk, ess_tail, r_hat]
# Index: []

# %%
exclude = {"tau_raw"}

var_names = [
    name for name in data.posterior.data_vars
    if name not in exclude
]

kwargs = dict(
    data=data, 
    var_names=var_names, 
    figsize=(20,12),
)

az.plot_trace(**kwargs)
plt.show()

# %% [markdown]
# ## N_CPS==3

# %%
N_CPS = 3
data = trace[N_CPS]

# %%
summary = az.summary(data=data)

COND1 = summary["ess_bulk"]<400
COND2 = summary["ess_tail"]<400
COND3 = summary["r_hat"]>1.01
COND4 = summary.index.str.contains("tau_raw")
summary[(COND1 | COND2 | COND3) & (~COND4)]
# Out:
#            mean      sd   hdi_3%  hdi_97%  mcse_mean  mcse_sd  ess_bulk  \
# mus[0]    1.370   0.046    1.288    1.452      0.006    0.000      61.0
# mus[1]    0.489   0.063    0.372    0.592      0.009    0.003      52.0
# mus[2]   -0.124   0.037   -0.195   -0.054      0.003    0.001     234.0
# tau[0]  149.132  11.725  136.000  165.000      1.998    0.106      45.0
# tau[1]  268.733   6.937  260.000  284.000      0.959    1.570     132.0
# tau[2]  404.255   4.222  394.000  409.000      0.227    0.218     695.0
#
#         ess_tail  r_hat
# mus[0]    1163.0   1.05
# mus[1]     143.0   1.06
# mus[2]     223.0   1.01
# tau[0]      53.0   1.07
# tau[1]      41.0   1.02
# tau[2]     299.0   1.01

# %%
exclude = {"tau_raw"}

var_names = [
    name for name in data.posterior.data_vars
    if name not in exclude
]

kwargs = dict(
    data=data, 
    var_names=var_names, 
    figsize=(20,12),
)

az.plot_trace(**kwargs)
plt.show()

# %% [markdown]
# ## N_CPS==4

# %%
N_CPS = 4
data = trace[N_CPS]

# %%
summary = az.summary(data=data)

COND1 = summary["ess_bulk"]<400
COND2 = summary["ess_tail"]<400
COND3 = summary["r_hat"]>1.01
COND4 = summary.index.str.contains("tau_raw")
summary[(COND1 | COND2 | COND3) & (~COND4)]
# Out:
#            mean      sd   hdi_3%  hdi_97%  mcse_mean  mcse_sd  ess_bulk  \
# mus[0]    1.375   0.045    1.294    1.454      0.006    0.000      55.0
# mus[1]    0.503   0.055    0.402    0.596      0.007    0.001      61.0
# mus[3]   -0.592   0.080   -0.746   -0.455      0.005    0.002     222.0
# tau[0]  147.210  11.408  136.000  164.000      2.050    0.183      42.0
# tau[2]  384.186   9.011  371.000  395.000      0.759    0.098     182.0
# tau[3]  440.208   8.449  431.000  466.000      0.505    0.567     441.0
#
#         ess_tail  r_hat
# mus[0]    1065.0   1.06
# mus[1]     787.0   1.05
# mus[3]     686.0   1.03
# tau[0]      45.0   1.08
# tau[2]    1026.0   1.02
# tau[3]     236.0   1.02

# %%
exclude = {"tau_raw"}

var_names = [
    name for name in data.posterior.data_vars
    if name not in exclude
]

kwargs = dict(
    data=data, 
    var_names=var_names, 
    figsize=(20,12),
)

az.plot_trace(**kwargs)
plt.show()

# %% [markdown]
# ## N_CPS==5

# %%
N_CPS = 5
data = trace[N_CPS]

# %%
summary = az.summary(data=data)

COND1 = summary["ess_bulk"]<400
COND2 = summary["ess_tail"]<400
COND3 = summary["r_hat"]>1.01
COND4 = summary.index.str.contains("tau_raw")
summary[(COND1 | COND2 | COND3) & (~COND4)]
# Out:
#            mean      sd   hdi_3%  hdi_97%  mcse_mean  mcse_sd  ess_bulk  \
# mus[1]    0.796   0.069    0.669    0.938      0.005    0.004     308.0
# mus[2]    0.348   0.059    0.247    0.462      0.004    0.001     216.0
# mus[3]   -0.102   0.048   -0.193   -0.015      0.004    0.001     169.0
# mus[4]   -0.623   0.071   -0.749   -0.488      0.006    0.001     144.0
# tau[1]  187.650   9.696  164.000  202.000      0.863    0.818     224.0
# tau[2]  278.854  12.411  264.000  296.000      0.903    0.131     222.0
# tau[3]  389.151   8.157  371.000  395.000      1.061    0.435      77.0
#
#         ess_tail  r_hat
# mus[1]     279.0   1.01
# mus[2]     442.0   1.02
# mus[3]     666.0   1.02
# mus[4]     794.0   1.02
# tau[1]     103.0   1.02
# tau[2]    2369.0   1.01
# tau[3]     416.0   1.05

# %%
exclude = {"tau_raw"}

var_names = [
    name for name in data.posterior.data_vars
    if name not in exclude
]

kwargs = dict(
    data=data, 
    var_names=var_names, 
    figsize=(20,12),
)

az.plot_trace(**kwargs)
plt.show()

# %% [markdown]
# # ppc

# %%
IC = "loo"

compare_dict = {
    f"cps{k}": obj
    for k, obj in trace.items()
}

kwargs = dict(
    compare_dict=compare_dict,
    ic=IC,
)
cmp = az.compare(**kwargs)

# %%
cmp
# Out:
#       rank    elpd_loo      p_loo   elpd_diff        weight         se  \
# cps5     0 -241.735489  38.251285    0.000000  8.853393e-01  21.424537
# cps4     1 -268.313684  45.408760   26.578195  1.242122e-13  20.508279
# cps3     2 -278.261711  35.326066   36.526221  3.155512e-02  19.526232
# cps2     3 -321.213638   8.397697   79.478148  4.991750e-02  19.818642
# cps1     4 -544.345123  14.085552  302.609634  3.318810e-02  13.571504
#
#             dse  warning scale
# cps5   0.000000     True   log
# cps4   6.588508     True   log
# cps3  10.256929     True   log
# cps2  14.160014     True   log
# cps1  21.265791     True   log

# %%
az.plot_compare(cmp)
plt.show()

# %% [markdown]
# # change point

# %%
FACTOR = 1
N_CPS = 2
TRACE = trace[N_CPS]

# %%
DATE = scores.index.to_timestamp()

kwargs = dict(
    trace=TRACE,
    date=DATE,
    factor=FACTOR,
)

analysis.posterior.main(**kwargs)

# %%
FIGSIZE = (16,6)

kwargs = dict(
    trace=TRACE,
    scores=scores,
    factor=FACTOR,
    figsize=FIGSIZE,
)

analysis.changepoint.main(**kwargs)
